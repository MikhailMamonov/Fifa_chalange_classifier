# %%
import pandas as pd
from os import path, makedirs
from matplotlib import pyplot as plt
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split

# %%
DATA_PATH = path.abspath("data/")
TEST_DATA_PATH = path.join(DATA_PATH, 'test')
TRAIN_DATA_PATH = path.join(DATA_PATH, 'train')
VALIDATION_DATA_PATH = path.join(DATA_PATH, 'validation')
DATA_FILE = path.join(DATA_PATH, 'data.csv')

# %%
DATA_PATH
# Out:
# 'C:\\Users\\mamon\\Documents\\FIFACellenge_scikitLearn\\src\\data\\'

# %%
data = pd.read_csv(path.join(DATA_PATH, 'data.csv'))

# %%
data.isnull()
# Out:
#        Unnamed: 0     ID   Name    Age  Photo  Nationality   Flag  Overall  \
# 0           False  False  False  False  False        False  False    False
# 1           False  False  False  False  False        False  False    False
# 2           False  False  False  False  False        False  False    False
# 3           False  False  False  False  False        False  False    False
# 4           False  False  False  False  False        False  False    False
# 5           False  False  False  False  False        False  False    False
# 6           False  False  False  False  False        False  False    False
# 7           False  False  False  False  False        False  False    False
# 8           False  False  False  False  False        False  False    False
# 9           False  False  False  False  False        False  False    False
# 10          False  False  False  False  False        False  False    False
# ...

# %%
modifedData=data.fillna(' ')

# %%
modifedData.to_csv('modifiedData.csv',index=False)

# %%
y = modifedData.Position
x = modifedData.drop('Position', axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=0.2)

# %%
#resultData = .replace({'Position': r'^\s*B$'}, {'Position': '1'}, regex=True)
data = pd.read_csv(path.join(DATA_PATH, 'data.csv')) 
r = data['Position'].str.replace(r'^\s*B', '1', regex = True)
print(r)
# Out:
# 0         RF
# 1         ST
# 2         LW
# 3         GK
# 4        RCM
# 5         LF
# 6        RCM
# 7         RS
# 8        RCB
# 9         GK
# 10        ST
# 11       LCM
# 12        CB
# 13       LCM
# 14       LDM
# 15        LF
# 16        ST
# 17       CAM
# 18        GK
# 19        GK
# 20       CDM
# 21        LS
# 22        GK
# 23        ST
# 24       LCB
# 25        RM
# 26        RM
# 27       CDM
# 28       LAM
# 29        LW
#         ...
# 18177     ST
# 18178     GK
# 18179     CB
# 18180     GK
# 18181     RB
# 18182    CDM
# 18183     GK
# 18184     CM
# 18185    LCM
# 18186     CM
# 18187     RB
# 18188     CM
# 18189     ST
# 18190     CM
# 18191     LB
# 18192    CDM
# 18193     RB
# 18194     GK
# 18195     CM
# 18196     CM
# 18197     CM
# 18198     GK
# 18199     CM
# 18200     ST
# 18201     RB
# 18202     CM
# 18203     ST
# 18204     ST
# 18205     RW
# 18206     CM
# Name: Position, Length: 18207, dtype: object
